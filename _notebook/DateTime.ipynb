// %% [markdown]
// # Дата и время

// %%
Console.WriteLine(DateTime.Now);

Console.WriteLine(DateTime.Now.Date.DayOfYear);
// Out:
// 10/5/2024 4:17:57 PM
// 279

// %%
Console.WriteLine(DateTime.Now.TimeOfDay);
Console.WriteLine(DateTime.Now.Hour);
// Out:
// 16:18:56.4386093
// 16

// %%
var dt = DateTime.Now;
Console.WriteLine($"{dt:yyyy-MM-dd}");
Console.WriteLine($"{dt:dd MMM yy}");
Console.WriteLine($"{dt:dd MMMM yy}");

// https://learn.microsoft.com/ru-ru/dotnet/standard/base-types/custom-date-and-time-format-strings
// Out:
// 2024-10-05
// 05 Oct 24
// 05 October 24

// %%
var dt = DateTime.Now;
Console.WriteLine($"{dt:HH:mm.ss}")
// Out:
// 16:25.04

// %%
var dt = new DateTime(1945, 5, 9);
Console.WriteLine(dt)
// Out:
// 5/9/1945 12:00:00 AM

// %%
//var dt = new DateOnly(1945, 5, 9);
var dt = new DateOnly(year: 1945, month: 5, day: 9);
Console.WriteLine(dt)
// Out:
// 5/9/1945

// %%
var timeStart = new TimeOnly(hour: 13, minute: 57);
Console.WriteLine(timeStart);
var timeEnd = timeStart.AddMinutes(40);
Console.WriteLine(timeEnd);
// Out:
// 1:57 PM
// 2:37 PM
